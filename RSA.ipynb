# %% [markdown]
# # Taller de criptografia

# %% [markdown]
# ## RSA
# proviene de los autores Rives - Shamir - Adle
# Para firmas y cifrado
# ## Version de TextBock RS (version sencilla)
# ¿que es un cifrado? -> es una operacion que recibe un mensaje y una llave que puede ser publica o privada
#
# por el servidor:
# tenemos una entidad con una llave (d) y un valor publico (n)
# por el cliente:
# Tenemos una llave publica (e) y un valor cliente
# ![image.png](attachment:a00ae4d2-b565-4bdc-ba19-eb4c1125323f.png)
#
# este pasa un mensaje(c) y lo expone y uso de mod(n)
# y eso llega al servidor
#
# m = C^d (mod n)
#
# ## Como se genera la llave?
#
# n = p *q (dos numeros primos aleatorios)
# e*d= 1 -> la llave publica y privada debe dar 1
# e = 65537 (aunque puede ser cualquier valor por estandarizado esta ese)
# d = e^-1
# Publico = n , e
# Privado = n , d

# %%
pip install pycryptodome
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gmpy2
# Out:
# ...
#
#   Using cached gmpy2-2.1.5.tar.gz (261 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build gmpy2
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [22 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-312
#   creating build\lib.win-amd64-cpython-312\gmpy2
#   copying gmpy2\__init__.py -> build\lib.win-amd64-cpython-312\gmpy2
#   running egg_info
#   writing gmpy2.egg-info\PKG-INFO
#   writing dependency_links to gmpy2.egg-info\dependency_links.txt
# ...

# %%
from Crypto. Util. number import getPrime
p = getPrime(1024) //se define 20 bits
q = getPrime(1024)

n = p*q
# Out:
#   Cell In[1], line 2
#     p = getPrime(1024) //se define 20 bits
#                             ^
# SyntaxError: invalid syntax
